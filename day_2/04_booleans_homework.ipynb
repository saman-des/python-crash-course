# %% [markdown]
# ---------------------------------------------------------
# HOMEWORK 4: BOOLEANS, type(), AND TYPE CONVERSION ✅❌
# ---------------------------------------------------------

# %% [markdown]
# TASK 1: Boolean Variables
#
# Create 4 boolean variables that describe something TRUE or FALSE about you.
# Examples: do_you_like_music, do_you_have_a_pet, do_you_like_mornings ...
# Write your variables below:

# %%
# Print each one with a short label, like:
# "Do I like music? True"
# Write your print statements below:

like_music = True
have_pet = True
like_mornings  = False

print(f"Music: {like_music} Have pet: {have_pet} Mornings: {like_mornings}")
# Out:
# Music: True Have pet: True Mornings: False

# %% [markdown]
# TASK 2: Comparison Operators
# Python will figure out the answer — your job is to predict it first!
# Write a comment next to each line saying what YOU think the answer is,
# then run the code and see if you were right.

# %%
age = 18
print(age == 18)   # your prediction: T
print(age > 20)    # your prediction: ?F
print(age < 21)    # your prediction: T
print(age != 15)   # your prediction: T
print(age >= 18)   # your prediction: T
# Out:
# True
# False
# True
# True
# True

# %% [markdown]
# TASK 3: type() Detective
# Create one variable of each type: str, int, float, bool.
# Print each value AND its type on the same line.
# Format: "Value: 42    Type: <class 'int'>"
# Write your code below:

# %%
my_str = "Python"
my_int = 42
my_float = 19.99
my_bool = True

print(f"Value: {my_str:<10} Type: {type(my_str)}")
print(f"Value: {my_int:<10} Type: {type(my_int)}")
print(f"Value: {my_float:<10} Type: {type(my_float)}")
print(f"Value: {my_bool:<10} Type: {type(my_bool)}")
# Out:
# Value: Python     Type: <class 'str'>
# Value: 42         Type: <class 'int'>
# Value: 19.99      Type: <class 'float'>
# Value: 1          Type: <class 'bool'>

# %% [markdown]
# TASK 4: Type Conversion + Input
# Ask the user for their birth year.
# Convert it to an integer.
# Calculate their approximate age (2024 - birth_year).
# Print: "You are approximately [age] years old!"
# Write your code below:

# %%
birth_year = int(input("Birth year"))

print(f"Your age is {2026 - birth_year}")
# Out:
# Your age is 26

# %% [markdown]
# ⭐ BONUS CHALLENGE:
# Ask the user for their exam score (0–100). Convert to int.
# Print True if the score is 40 or above (passing), False if not.
# Hint: use a comparison operator directly inside print().
# Write your code below:
